# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep

service_ = Service(ChromeDriverManager().install())
browser = webdriver.Chrome(service=service_)

#URL dictionary  
videos_dict = {'Simple Plan': ['https://www.youtube.com/watch?v=b1Ny_C5XGNQ', 
                           'https://youtu.be/n5oTbOYR84o?si=iGtly1jjpxgf8TRc', 
                           'https://youtu.be/_GOR5gvQwDI?si=QkP64FZXndpW2J95'],
               'Linkin Park':['https://youtu.be/pQto8npSUC0?si=16GYDoDhWAeELj_C',
                        'https://youtu.be/7NK_JOkuSVY?si=U7Wk538HD3P4AkpI',
                        'https://youtu.be/kXYiU_JCYtU?si=M7aqK7mKVJSeFBA8']}

# %%
from selenium.webdriver.common.by import By

#Data = {name of video: [name of the band, number of views, number of likes]}

videos_data = {}

for band in videos_dict:
    values = []
    
    for video in videos_dict[band]:
        
        browser.get(video)
        sleep(2.5)
        
        #Name of the video
        video_name = browser.find_element(By.XPATH, '//*[@id="title"]/h1/yt-formatted-string').text
        videos_data[video_name] = None
        
        #Name of the band:
        band_name = browser.find_element(By.XPATH, '//*[@id="text"]/a').text
        values.append(band_name)
        
        #Views number
        number_of_views = browser.find_element(By.XPATH, '//*[@id="info"]/span[1]').text
        values.append(number_of_views)
        
        #Likes number
        number_of_likes = browser.find_element(By.XPATH, '//*[@id="top-level-buttons-computed"]/segmented-like-dislike-button-view-model/yt-smartimation/div/div/like-button-view-model/toggle-button-view-model/button/div[2]').text
        values.append(number_of_likes)
        
        videos_data[video_name] = values
        
videos_data

# %%
# Out:
# {'Simple Plan- Ruin My Life feat. Deryck Whibley (Official Music Video)': ['SimplePlan',
#   '3,8 mi de visualizações',
#   '102 mil',
#   'SimplePlan',
#   '2 mi de visualizações',
#   '55 mil',
#   'SimplePlan',
#   '60 mi de visualizações',
#   '713 mil'],
#  'Simple Plan - The Antidote (Official Music Video)': ['SimplePlan',
#   '3,8 mi de visualizações',
#   '102 mil',
#   'SimplePlan',
#   '2 mi de visualizações',
#   '55 mil',
#   'SimplePlan',
#   '60 mi de visualizações',
#   '713 mil'],
#  "Simple Plan - I'm Just A Kid (Official Video) [HD]": ['SimplePlan',
#   '3,8 mi de visualizações',
#   '102 mil',
#   'SimplePlan',
#   '2 mi de visualizações',
#   '55 mil',
#   'SimplePlan',
#   '60 mi de visualizações',
#   '713 mil'],
#  'Linkin Park - In the End (Live In Texas)': ['Linkin Park',
#   '2,1 mi de visualizações',
#   '27 mil',
#   'Linkin Park',
#   '72 mi de visualizações',
#   '1,7 mi',
#   'Linkin Park',
#   '2,1 bi de visualizações',
#   '13 mi'],
#  'Lost [Official Music Video] - Linkin Park': ['Linkin Park',
#   '2,1 mi de visualizações',
#   '27 mil',
#   'Linkin Park',
#   '72 mi de visualizações',
#   '1,7 mi',
#   'Linkin Park',
#   '2,1 bi de visualizações',
#   '13 mi'],
#  'Numb (Official Music Video) [4K UPGRADE] – Linkin Park': ['Linkin Park',
#   '2,1 mi de visualizações',
#   '27 mil',
#   'Linkin Park',
#   '72 mi de visualizações',
#   '1,7 mi',
#   'Linkin Park',
#   '2,1 bi de visualizações',
#   '13 mi']}
